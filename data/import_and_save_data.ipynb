# %%
# !pip install pybaseball
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.9/375.9 kB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 38.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import pybaseball

# %%
raw22 = pybaseball.statcast(start_dt = '2022-01-01', end_dt = '2022-12-31')
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 246/246 [06:06<00:00,  1.49s/it]

# %%
raw21 = pybaseball.statcast(start_dt = '2021-01-01', end_dt = '2021-12-31')
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 246/246 [05:56<00:00,  1.45s/it]

# %%
raw20 = pybaseball.statcast(start_dt = '2020-01-01', end_dt = '2020-12-31')
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 97/97 [02:18<00:00,  1.42s/it]

# %%
raw19 = pybaseball.statcast(start_dt = '2019-01-01', end_dt = '2019-12-31')
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 225/225 [06:01<00:00,  1.61s/it]

# %%
raw18 = pybaseball.statcast(start_dt = '2018-01-01', end_dt = '2018-12-31')
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 214/214 [05:49<00:00,  1.64s/it]

# %%
from google.colab import drive
drive.mount('/drive')

raw22.to_csv('/drive/My Drive/Colab Notebooks/sequencing_positioning_journal_paper/data/raw22.csv', index = False)
raw21.to_csv('/drive/My Drive/Colab Notebooks/sequencing_positioning_journal_paper/data/raw21.csv', index = False)
raw20.to_csv('/drive/My Drive/Colab Notebooks/sequencing_positioning_journal_paper/data/raw20.csv', index = False)
raw19.to_csv('/drive/My Drive/Colab Notebooks/sequencing_positioning_journal_paper/data/raw19.csv', index = False)
raw18.to_csv('/drive/My Drive/Colab Notebooks/sequencing_positioning_journal_paper/data/raw18.csv', index = False)
# Out:
# Mounted at /drive

# %%
raw23 = pybaseball.statcast(start_dt = '2023-01-01', end_dt = '2023-12-31')
# Out:
# This is a large query, it may take a moment to complete
# /usr/local/lib/python3.10/dist-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# Skipping offseason dates
# ...

# %%
from google.colab import drive
drive.mount('/drive')

raw23.to_csv('/drive/My Drive/Colab Notebooks/sequencing_positioning_journal_paper/data/raw23.csv', index = False)
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/drive')

raw23 = pd.read_csv('/drive/My Drive/Colab Notebooks/sequencing_positioning_journal_paper/data/raw23.csv')
# Out:
# Mounted at /drive

# %%
raw23.events.unique()
# Out:
# array(['strikeout', nan, 'field_out', 'single', 'home_run', 'walk',
#        'fielders_choice_out', 'double', 'sac_bunt', 'force_out',
#        'grounded_into_double_play', 'hit_by_pitch', 'sac_fly',
#        'fielders_choice', 'triple', 'caught_stealing_2b', 'other_out',
#        'field_error', 'double_play', 'catcher_interf',
#        'strikeout_double_play', 'pickoff_caught_stealing_2b',
#        'stolen_base_3b', 'caught_stealing_home', 'sac_fly_double_play',
#        'pickoff_1b', 'caught_stealing_3b', 'wild_pitch', 'stolen_base_2b',
#        'pickoff_3b', 'pickoff_2b', 'pickoff_error_3b', 'triple_play',
#        'pickoff_caught_stealing_home'], dtype=object)
